# %% [raw]
# Question 1.Find the val%e of T(2) for the rec%rrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.
#
#
# This recurrence relation (T(n) = 3T(n-1) + 12n) defines a function where the value of (T(n)) depends on the previous value (T(n-1))
# and the input  (n ).
#
# To find  (T(2) ), we will use the given recurrence relation and the base case (T(0) = 5).
#
# Given:
# (T(0) = 5)
#
# Using the recurrence relation (T(n) = 3T(n-1) + 12n):
#
# (T(1) = 3T(1-1) + 12(1) = 3T(0) + 12 = 3 times 5 + 12 = 15 + 12 = 27)
#
# (T(2) = 3T(2-1) + 12(2) = 3T(1) + 24 = 3 times 27 + 24 = 81 + 24 = 105)
#
# So, the value of (T(2)) for the given recurrence relation and base case is (105).

# %% [raw]
# Question 2. Given a recurrence relation, solve it using the substitution method:
# a. T(n) = T(n-1) + c
#
#
# =>  Sure, to solve the recurrence relation (T(n) = T(n-1) + c) using the substitution method,
# we will try to find a pattern and derive a closed-form expression for (T(n)).
#
# Given:
# (T(n) = T(n-1) + c)
#
# Let's start with the base case:
#
# (T(1) = T(1-1) + c = T(0) + c)
#
# Now, let's try to establish a pattern by expanding (T(2), T(3)) and so on:
#
# (T(2) = T(2-1) + c = T(1) + c = (T(0) + c) + c = T(0) + 2c)
#
# (T(3) = T(3-1) + c = T(2) + c = (T(0) + 2c) + c = T(0) + 3c)
#
# From this pattern, we can generalize:
#
# (T(n) = T(0) + nc)
#
# So, in terms of (n) and the constant (c), the solution to the recurrence relation (T(n) = T(n-1) + c) using the substitution method is:
#
# [T(n) = T(0) + nc]
#
# This solution provides a closed-form expression for (T(n)) in terms of the initial condition (T(0)) and the constant (c), where
# (n) is the number of steps or iterations.
#
#
#
#
#
#
#
#
# b. (T(n) = 2T(n/2) + n)
#
# Let's assume (n = 2^k) for some non-negative integer (k). Then, (n/2 = 2^{k-1}).
#
# [T(2^k) = 2T(2^{k-1}) + 2^k]
#
# Let (S(k) = T(2^k)). Then the equation becomes:
#
# [S(k) = 2S(k-1) + 2^k]
#
# Now, let's solve this recurrence relation by iteratively substituting:
#
# [S(k) = 2S(k-1) + 2^k]
# [= 2(2S(k-2) + 2^{k-1}) + 2^k]
# [= 2^2S(k-2) + 2^k + 2^k]
# [= 2^2S(k-2) + 2.2^k]
#
# Continuing this process, after (m) steps, we get:
#
# [S(k) = 2^mS(k-m) + m.2^k]
#
# When (k = m), (S(k-m) = S(0)) (the base case).
#
# So, when (k = m = log_2 n), we get:
#
# [S(log_2 n) = 2^{log_2 n}S(0) + log_2 n.2^{log_2 n}]
# [= nS(0) + nlog_2 n]
#
# Therefore, (T(n) = nT(1) + nlog_2 n = nT(1) + nlog ) (as log_2 n = log n log 2)).
#
#
#
#
#
# c. (T(n) = 2T(n/2) + c)
#
# Following a similar process as before:
#
# Let's assume  (n = 2^k ) for some non-negative integer  (k ).
#
#  [T(2^k) = 2T(2^{k-1}) + c ]
#
# Let  (S(k) = T(2^k) ). Then the equation becomes:
#
#  [S(k) = 2S(k-1) + c ]
#
# Solving this recurrence relation follows a similar pattern to the first one, and after  (k =  log_2 n ) steps:
#
#  [S( log_2 n) = nT(1) + c  cdot  log_2 n = nT(1) + c  cdot  log n ]
#
#
#
#
#
# d.  (T(n) = T(n/2) + c )
#
# Let's assume  (n = 2^k ) for some non-negative integer  (k ).
#
#  [T(2^k) = T(2^{k-1}) + c ]
#
# Let  (S(k) = T(2^k) ). Then the equation becomes:
#
#  [S(k) = S(k-1) + c ]
#
# After  (k =  log_2 n ) steps:
#
#  [S( log_2 n) = S(0) + c  cdot  log_2 n = T(1) + c  cdot  log n ]
#
# These solutions provide closed-form expressions for  (T(n) ) in terms of the initial conditions and the specific patterns observed in each recurrence relation.

# %% [raw]
# Question 3. Given a recurrence relation, solve it using the recursive tree approach:
# a. T(n) = 2T(n-1) +1
# b. T(n) = 2T(n/2) + n
#
#
#
# Let's solve these recurrence relations using the recursive tree approach:
#
# ### a.  (T(n) = 2T(n-1) + 1 )
#
# This recurrence relation implies that at each step, the function  (T(n) ) is dependent on twice the value of  (T ) at the previous step ( (T(n-1) )) plus 1.
#
# To visualize this using a recursive tree:
#
# ```
#                            T(n)
#                           /    \
#                    T(n-1)+1   T(n-1)+1
#                      /          /
#             T(n-2)+1 T(n-2)+1 T(n-2)+1 T(n-2)+1
#                . . .
# ```
#
# The tree shows that at each level, there are two branches, each contributing 1. This forms a binary tree with a depth of  (n ) levels.
#
# If we sum up the number of nodes at each level of this tree, we get a geometric series:
#
#  [ text{Total number of nodes} = 1 + 2 + 4 +  dots + 2^n = 2^{n+1} - 1 ]
#
# Therefore, the time complexity of this recurrence relation is exponential, specifically  (O(2^n) ).
#
# ### b.  (T(n) = 2T(n/2) + n )
#
# This recurrence relation represents a divide-and-conquer algorithm where the problem is divided into two equal parts at each step, and the solution involves the sum of the problem size ( (n )).
#
# The recursive tree for this relation would look like:
#
# ```
#                         T(n)
#                       /      \
#                   T(n/2)+n  T(n/2)+n
#                    /          /
#               T(n/4)+n T(n/4)+n ...
# ```
#
# Here, at each level, the value of  (n ) reduces by half (as  (n/2 )) at each subsequent level. The depth of this tree would be  ( log n ) because the problem size is halved at each step.
#
# To calculate the total work done, we sum the work at each level of the tree. At level  (i ), there are  (2^i ) nodes, each contributing  (n/2^i ). Therefore, the total work is:
#
#  [T(n) = n log n + n left( log n - 1 right) +  dots + n = O(n  log n) ]
#
# So, the time complexity of this recurrence relation  (T(n) = 2T(n/2) + n ) is  (O(n  log n) ).
